# %% [markdown]
# # Оглавление
#
# ## Неделя
#
# ### [Строки и байты](1/1.3.3_str_and_bytes.ipynb)
# 1. Базовые типы: Строки и байтовые строки
#   * Определение типа объекта
#   * Объединение строк
#   * Размножение строк
#   * Строки - это неизменяемый тип данных
#   * Срезы строк
#   * Методы строк
#   * Оператор `IN`
#   * Оператор `FOR ... IN`
#   * Конвертация типов
#   * Форматирование строк
# 2. Байтовые строки. Тип `bytes`
#
# ### [Базовые типы: Объект None](1/1.3.4.object_none.ipynb)
#
# ### [Конструкции управления потоком](1/1.3.5-1.3.6.managment_flow.ipynb)
#
# 1. `if` - проверка условия
# 2. `if-else`
# 3. `if-elif-else`
# 4. Аналог тернарного оператора
# 5. Оператор `while`
# 6. Цикл `for`, объект `range()`
# 7. Оператор `break`
# 8. Оператор `continue`
# 9. Пример на управление потоком
#
# ### [Создание виртуальной среды](1/1.4.2_venv_jupyter.ipynb)
#
# 1. Установка пакета
#   * Создание виртуальной среды
#   * Активация виртуального окружения
# 2. Деактивация виртуального окружения
# 3. Устанавливаем пакет `jupyter`
# 4. Запуск web-приложения `jupyter-notebook`
# 5. Установка тем `jupyter-themes`
#
# ### [Приложение использующее сервис freegeoip.net](1/1.4.4_requests_freegeoip.ipynb)
#
# ### [Объектная структура в Python](1/1.4.5_objects.ipynb)
#
# ### [Байткод](1/1.4.6_bytecode.ipynb)

# %% [markdown]
# ## Неделя
#
# ### [Списки и кортежи](2/2.1.1_list_and_tuple.ipynb)
#
# 1. Списки
#   * Длина списков
#   * Индексы и срезы
#   * Итерация по списку
#   * Добавление и удаление элементов списка
#   * `min`, `max`, `sum`, `str.join`
#   * Сортировка
# 2. Кортежи
# 3. Итоги
# 4. Списки. Пример программы "Медиана"
#
# ### [Словари](2/2.1.3_dictionary.ipynb)
#
# 1. Добавление и удаление элементов
# 2. Итерация
# 3. `OrderedDict`
# 4. Итоги
# 5. Словари. Пример программы
#
# ### [Множества](2/2.1.5_set.ipynb)
#
# 1. Множество `fozenset`
# 2. Итоги
# 3. Множество. Пример программы
#
# ### [Функции](2/2.2.1_function.ipynb)
#
# 1. Аннотация типов
# 2. По ссылке или по значению?
# 3. Именованные аргументы
# 4. Область видимости
# 5. Аргументы по умолчанию
# 6. Звездочки в аргументах. Распаковка аргументов
#
# ### [Файлы](2/2.2.2_files.ipynb)
#
# ### [Функциональное программирование](2/2.2.3_func_programming.ipynb)
#
# 1. Замыкания (closure)
# 2. Функция `map`
# 3. Функция `filter`
# 4. `lambda` (Анонимные функции)
# 5. Модуль `functools`
#   * Функция `reduce`
#   * Функция `partial`
# 6. Списочные выражения. Генератор
# 7. Функция `zip`
# 8. Итоги. Функциональное программирование
#
# ### [Декораторы](2/2.2.4_decorator.ipynb)
#
# 1. Пример декоратора `logger`
# 2. Более сложный пример `logger'a`
# 3. Применение нескольких декораторов подряд
#
# ### [Генераторы](2/2.2.5_generators.ipynb)
#
# 1. Возможность генератором получать значения

# %% [markdown]
# ## Неделя
#
# ### [Классы и экземпляры. Часть 1](3/3.1.1_classes_and_objects_1.ipynb)
#
# 1. Объявление класса
# 2. Создание экземпляра класса (объекта)
# 3. Инициализация экземпляра класса (объекта)
# 4. Население солнечной системы планетами со своими именами
# 5. Работа с атрибутами класса
# 6. Итоги
#
# ### [Классы и экземпляры. Часть 2](3/3.1.2_classes_and_objects_2.ipynb)
#
# 1. Атрибуты класса
# 2. Деструктор класса
# 3. Словарь атрибутов `__dict__`
# 4. Список атрибутов. Функция `dir()`
# 5. Магические атрибуты
# 6. Конструктор экземпляра класса
# 7. Итоги
#
# ### [Методы. Часть 1](3/3.1.3_methods_1.ipynb)
#
# 1. Вызов методов из методов
# 2. Метод класса. Декоратор `@classmethod`
# 3. Итоги
#
# ### [Методы. Часть 2](3/3.1.4_methods_2.ipynb)
#
# 1. Статический метод класса `@staticmethod`
# 2. Вычисляемые свойства класса (класс `property`)
# 3. Декоратор `@property`
# 4. Итоги
#
# ### [Пример программы получающей прогноз погоды](3/3.1.5_example_yahoo_forecast.ipynb)
#
# ### [Наследование в Python](3/3.2.1_inheritance.ipynb)
#
# 1. Множественное наследование
# 2. Наследование от `object` (`issubclass`)
# 3. Объект является экземпляром класса? (`isinstance`)
# 4. Поиск атрибутов и методов объекта. Линеаризация класса (MRO)
# 5. Использование `super()`
# 6. Разрешение конфликта имен, `name mangling`
# 7. Итоги
#
# ### [Композиция классов](3/3.2.2_compose.ipynb)
#
# 1. Композиция или наследование?
# 2. Улучшенная версия экспорта
#
# ### [Классы исключений и их обработка](3/3.3.1_exceptions.ipynb)
#
# 1. Обработка исключений
# 2. Обработка ожидаемого исключения
# 3. Блок `else`
# 4. Обработка нескольких исключений
# 5. Обработка нескольких исключений, наследование
# 6. Блок `finally`
# 7. Итоги
#
# ### [Генерация исключений](3/3.3.2_generation_exceptions.ipynb)
#
# 1. Доступ к объекту исключения
# 2. Доступ к объекту исключения, атрибут `args`
# 3. Доступ к стеку вызовов
# 4. Генерация исключения, инструкция `raise`
# 5. Проброс исключения выше по стеку
# 6. Исключение через `raise from Exception`
# 7. Инструкция `assert`
# 8. Производительность исключений
# 9. Итоги

# %% [markdown]
# ## Неделя
#
# ### [Демонстрация магических методов](4/4.1.1_demo_magic_methods.ipynb)
#
# 1. Атрибут `__name__`
# 2. Атрибут `__module__`
# 3. Атрибут `__class__`
# 4. Атрибут `__code__`
# 5. Атрибут `__bases__`
# 6. Метод `__subclasses__()`
# 7. Атрибут `__mro__`
# 8. Атрибут `__doc__`
# 9. Метод `__str__()`
# 10. Метод `__repr__()`
# 11. Метод `__dir__()`
# 12. Атрибут `__defaults__`
# 13. Атрибут `__slots__`
# 14. Атрибут `__dict__`
# 15. Атрибут `__file__`
# 16. Метод `__hash__()`
# 17. Метод `__eq__()`
# 18. Метод `__getattr__()`
# 19. Метод `__getattribute__()`
# 20. Метод `__setattr__()`
# 21. Дескриптор. Метод `__get__()`
# 22. Дескиптор. Метод `__set__()`
# 23. Дескиптор. Метод `__delete__()`
# 24. Метод `__call__()`
# 25. Метод `__add__()`
# 26. Метод `__setitem__()`
# 27. Метод `__getitem__()`
# 28. Методы `__iter__()` и `__next__()`
# 29. Методы `__enter__()` и `__exit__()`
#
# ### [Магические методы](4/4.1.1_magic_methods.ipynb)
#
# 1. Методы `__new__`, `__init__`, `__str__`, `__hash__`, `__eq__`
# 2. Метод `__new__` и шаблон `singleton`
# 3. Методы `__getattr__`, `__getattribute__`, `__setattr__`, `__delattr__`
# 4. Метод `__call__`
# 5. Метод `__add__`
# 6. Метод `__getitem__`, `__setitem__`
#
# ### [Итераторы](4/4.1.2_iterators.ipynb)
#
# 1. Собственный итератор
# 2. Собственный итератор без реализации методов `__iter__` и `__next__`
#
# ### [Контекстный менеджер](4/4.1.3_context_manager.ipynb)
#
# 1. Определяем пользовательский контекстный менеджер
# 2. Исключения внутри блока контекстного менеджера
# 3. Подсчет времени выполнения кода с помощью блока контекстного менеджера
# 4. Еще один пример применения контекстного менеджера
#
# ### [Дескрипторы](4/4.2.1_decriptors.ipynb)
#
# 1. Пример дескриптора № 1
# 2. Пример дескриптора № 2
# 3. Пример дескриптора № 3
# 4. Функции и методы
# 5. Декоратор `@property`
# 6. Собственный класс который эмулирует поведение `@property`
# 7. `@staticmethod` и `@classmethod` реализованы через дескрипторы
# 8. `__slots__` также работает с помощью дескрипторов
#
# ### [Метаклассы](4/4.2.2_metaclasses.ipynb)
#
# 1. Создание классов
# 2. Собственный метакласс и метод `__new__`
# 3. Собственный метакласс и метод `__init__`
# 4. Абстрактные методы
#
# ### [Отладка](4/4.3.1_debugging.ipynb)
#
# ### [Тестирование](4/4.3.2_testing.ipynb)

# %% [markdown]
# ## Неделя
#
# ### [Процесс и его характеристики](5/5.1.2_process.ipynb)
#
# 1. Простой Python процесс
#
# ### [Создание процессов](5/5.1.3_creating_process.ipynb)
#
# 1. Пример №1
# 2. Пример №2
# 3. Пример №3
# 4. Пример №4
# 5. Итоги
#
# ### [Создание потоков](5/5.1.4_creating_threads.ipynb)
#
# 1. Пул потоков - `ThreadPoolExecutor`
# 2. Итоги
#
# ### [Синхронизация потоков](5/5.1.5_sync_threads.ipynb)
#
# 1. Очереди. Модуль `queue`
# 2. Синхронизация потоков, блокировки
# 3. Еще вариант применения блокировок
# 4. Синхронизация потоков, условные переменные
# 5. Итоги
#
# ### [GIL. Глобальная блокировка интерпретатора](5/5.1.6_gil.ipynb)
#
# 1. CPU bound program
# 2. GIL, подводим итоги
#
# ### [Сокеты. Клиент-сервер](5/5.2.1_socket.ipynb)
#
# 1. Создание сокета
#   * Сервер
#   * Клиент
# 2. Создание сокета. Контекстный менеджер
#   * Сервер
#   * Клиент
# 3. Таймауты и обработка сетевых ошибок
#   * Сервер
#   * Клиент
# 4. Обработка нескольких соединений. Потоки
#   * Сервер
# 5. Обработка нескольких соединений. Потоки и процессы одновременно
#   * Сервер
#
# ### [Исполнение кода в одном потоке, модуль `select`](5/5.3.1_socket_module_select.ipynb)
#
# 1. Неблокирующий ввод/вывод. Обучающий пример
#
# ### [Итераторы и генераторы, в чём разница?](5/5.3.2_iterator_vs_generator.ipynb)
#
# 1. Итераторы
# 2. Генераторы
# 3. Итоги
#
# ### [Генераторы и сопрограммы (coroutine)](5/5.3.3_generators_and_coroutines.ipynb)
#
# 1. Coroutine. Метод `close()`
# 2. Coroutine. Метод `throw()`
# 3. Coroutine. Вызов `coroutine` из обычной функции
# 4. Coroutine. Инструкция `yield from`
# 5. PEP 380. Генераторы
# 6. Итоги
#
# ### [Первые шаги с `asyncio`](5/5.3.4_asyncio_first_steps.ipynb)
#
# 1. Итоги
# 2. Пример асинхронного клиента
#
# ### [Framework asyncio.Future](5/5.3.5_asyncio.ipynb)
#
# 1. Framework `asyncio.Task`
# 2. Framework `asyncio loop.run_in_executor()`
# 3. Итоги
